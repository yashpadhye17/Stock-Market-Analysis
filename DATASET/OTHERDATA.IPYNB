# %%
import pandas as pd
import numpy as np

# %%
vidharbha=pd.read_csv("https://data.nasdaq.com/api/v3/datasets/BSE/BOM504991.csv?api_key=hQ1m5NeC8pAcFbhW5xBE")

# %%
vidharbha
# Out:
#            Date   Open   High    Low  Close   WAP  No. of Shares  \
# 0    2009-10-05   1.00   1.00   1.00   1.00  1.00           50.0
# 1    2000-02-01   1.05   1.05   1.05   1.05  1.05          150.0
# 2    1999-12-27   1.00   1.00   1.00   1.00  1.00          200.0
# 3    1999-09-03   1.40   1.40   1.40   1.40  1.40          100.0
# 4    1999-08-13   1.45   1.45   1.45   1.45  1.44           50.0
# ..          ...    ...    ...    ...    ...   ...            ...
# 444  1991-01-14  12.50  15.00  12.50  15.00  0.00            0.0
# 445  1991-01-11  12.50  12.50  12.00  12.50  0.00            0.0
# 446  1991-01-09  12.50  15.00  12.50  15.00  0.00            0.0
# 447  1991-01-07  12.50  15.00  12.50  15.00  0.00            0.0
# 448  1991-01-03  15.00  15.00  15.00  15.00  0.00            0.0
#
#      No. of Trades  Total Turnover  Deliverable Quantity  \
# 0              1.0            50.0                  50.0
# 1              1.0           157.0                   NaN
# ...

# %%
vidharbha.drop(columns =['WAP','No. of Shares','No. of Trades','Total Turnover','Deliverable Quantity','% Deli. Qty to Traded Qty','Spread H-L','Spread C-O'])
# Out:
#            Date   Open   High    Low  Close
# 0    2009-10-05   1.00   1.00   1.00   1.00
# 1    2000-02-01   1.05   1.05   1.05   1.05
# 2    1999-12-27   1.00   1.00   1.00   1.00
# 3    1999-09-03   1.40   1.40   1.40   1.40
# 4    1999-08-13   1.45   1.45   1.45   1.45
# ..          ...    ...    ...    ...    ...
# 444  1991-01-14  12.50  15.00  12.50  15.00
# 445  1991-01-11  12.50  12.50  12.00  12.50
# 446  1991-01-09  12.50  15.00  12.50  15.00
# 447  1991-01-07  12.50  15.00  12.50  15.00
# 448  1991-01-03  15.00  15.00  15.00  15.00
#
# [449 rows x 5 columns]

# %%
quickheal=pd.read_csv("https://data.nasdaq.com/api/v3/datasets/BSE/BOM539678.csv?api_key=hQ1m5NeC8pAcFbhW5xBE")

# %%
quickheal
# Out:
#             Date    Open    High     Low   Close     WAP  No. of Shares  \
# 0     2022-05-18  177.45  183.80  176.95  179.80  179.83         8297.0
# 1     2022-05-17  179.45  179.45  175.25  177.45  177.09         6274.0
# 2     2022-05-16  175.00  182.00  172.50  176.40  178.53         7291.0
# 3     2022-05-13  168.60  182.45  168.60  177.35  177.53         5323.0
# 4     2022-05-12  175.00  175.00  170.15  171.05  171.47        10258.0
# ...          ...     ...     ...     ...     ...     ...            ...
# 1291  2017-02-28  248.50  253.50  247.60  248.50  249.88        66735.0
# 1292  2017-02-27  251.40  252.00  244.00  247.50  249.58        28019.0
# 1293  2017-02-23  253.30  254.60  249.20  250.55  251.99        26262.0
# 1294  2017-02-22  257.00  261.00  252.60  253.05  256.18        35603.0
# 1295  2017-02-21  254.25  259.50  253.00  257.75  257.17        40544.0
#
#       No. of Trades  Total Turnover  Deliverable Quantity  \
# ...

# %%
quickheal.drop(columns =['WAP','No. of Shares','No. of Trades','Total Turnover','Deliverable Quantity','% Deli. Qty to Traded Qty','Spread H-L','Spread C-O'])
# Out:
#             Date    Open    High     Low   Close
# 0     2022-05-18  177.45  183.80  176.95  179.80
# 1     2022-05-17  179.45  179.45  175.25  177.45
# 2     2022-05-16  175.00  182.00  172.50  176.40
# 3     2022-05-13  168.60  182.45  168.60  177.35
# 4     2022-05-12  175.00  175.00  170.15  171.05
# ...          ...     ...     ...     ...     ...
# 1291  2017-02-28  248.50  253.50  247.60  248.50
# 1292  2017-02-27  251.40  252.00  244.00  247.50
# 1293  2017-02-23  253.30  254.60  249.20  250.55
# 1294  2017-02-22  257.00  261.00  252.60  253.05
# 1295  2017-02-21  254.25  259.50  253.00  257.75
#
# [1296 rows x 5 columns]

# %%
midcap=pd.read_csv("https://data.nasdaq.com/api/v3/datasets/BSE/BSEMID.csv?api_key=hQ1m5NeC8pAcFbhW5xBE")

# %%
midcap
# Out:
#             Date      Open      High       Low     Close
# 0     2022-05-17  22325.13  22724.20  22232.15  22700.87
# 1     2022-05-16  21983.02  22189.31  21773.55  22145.10
# 2     2022-05-13  21873.65  22232.68  21764.22  21815.66
# 3     2022-05-12  22045.24  22045.24  21463.02  21645.13
# 4     2022-05-11  22332.34  22484.23  21757.60  22140.97
# ...          ...       ...       ...       ...       ...
# 4745  2003-04-07       NaN       NaN       NaN    971.63
# 4746  2003-04-04       NaN       NaN       NaN    949.65
# 4747  2003-04-03       NaN       NaN       NaN    929.82
# 4748  2003-04-02       NaN       NaN       NaN    916.53
# 4749  2003-04-01       NaN       NaN       NaN    899.23
#
# [4750 rows x 5 columns]

# %%
midcap=midcap.dropna()

# %%
midcap
# Out:
#             Date      Open      High       Low     Close
# 0     2022-05-17  22325.13  22724.20  22232.15  22700.87
# 1     2022-05-16  21983.02  22189.31  21773.55  22145.10
# 2     2022-05-13  21873.65  22232.68  21764.22  21815.66
# 3     2022-05-12  22045.24  22045.24  21463.02  21645.13
# 4     2022-05-11  22332.34  22484.23  21757.60  22140.97
# ...          ...       ...       ...       ...       ...
# 1750  2015-04-22  10538.84  10570.33  10402.03  10546.24
# 1751  2015-04-21  10578.38  10619.80  10476.11  10506.71
# 1752  2015-04-20  10787.13  10797.38  10481.55  10553.96
# 1753  2015-04-17  11013.99  11013.99  10755.13  10771.77
# 1754  2015-04-16  11100.59  11117.38  10913.38  10993.02
#
# [1755 rows x 5 columns]

# %%
BSE100=pd.read_csv("https://data.nasdaq.com/api/v3/datasets/BSE/BSE100.csv?api_key=hQ1m5NeC8pAcFbhW5xBE")

# %%
BSE100=BSE100.dropna()

# %%
BSE100
# Out:
#             Date      Open      High       Low     Close
# 0     2022-05-17  16311.85  16645.93  16269.97  16622.35
# 1     2022-05-16  16179.25  16312.87  16063.70  16198.64
# 2     2022-05-13  16327.59  16436.06  16057.98  16103.87
# 3     2022-05-12  16389.81  16390.88  16058.19  16134.11
# 4     2022-05-11  16620.00  16685.87  16315.64  16512.83
# ...          ...       ...       ...       ...       ...
# 7607  1991-01-11    294.33    300.91    294.00    300.77
# 7608  1991-01-09    294.01    296.93    293.65    296.35
# 7609  1991-01-07    293.59    295.39    290.42    295.39
# 7610  1991-01-03    292.27    294.41    289.01    289.04
# 7611  1991-01-02    304.01    304.01    293.93    293.93
#
# [7577 rows x 5 columns]

# %%
BSE200=pd.read_csv("https://data.nasdaq.com/api/v3/datasets/BSE/BSE200.csv?api_key=hQ1m5NeC8pAcFbhW5xBE")

# %%
BSE200=BSE200.dropna()

# %%
BSE200
# Out:
#             Date     Open     High      Low    Close
# 0     2022-05-17  6936.46  7078.38  6919.62  7068.52
# 1     2022-05-16  6876.18  6930.84  6825.78  6887.71
# 2     2022-05-13  6929.27  6981.12  6823.70  6842.25
# 3     2022-05-12  6957.52  6957.57  6814.08  6848.90
# 4     2022-05-11  7058.14  7087.39  6919.44  7008.44
# ...          ...      ...      ...      ...      ...
# 6345  1996-10-23   316.52   326.35   312.33   326.35
# 6346  1996-10-22   304.22   316.13   304.22   316.09
# 6347  1996-10-18   301.28   308.24   300.28   308.24
# 6348  1996-10-17   306.90   307.12   298.76   307.12
# 6349  1996-10-16   307.97   307.97   301.51   307.12
#
# [6347 rows x 5 columns]

# %%
BSE500=pd.read_csv("https://data.nasdaq.com/api/v3/datasets/BSE/BSE500.csv?api_key=hQ1m5NeC8pAcFbhW5xBE")

# %%
BSE500=BSE500.dropna()

# %%
BSE500
# Out:
#             Date      Open      High       Low     Close
# 0     2022-05-17  21767.51  22211.31  21715.22  22181.67
# 1     2022-05-16  21572.61  21734.49  21406.40  21614.97
# 2     2022-05-13  21708.73  21883.06  21402.17  21458.89
# 3     2022-05-12  21790.63  21790.85  21343.16  21457.70
# 4     2022-05-11  22143.90  22234.61  21663.60  21950.02
# ...          ...       ...       ...       ...       ...
# 5660  1999-08-13   1357.41   1359.21   1337.78   1340.85
# 5661  1999-08-12   1357.21   1363.76   1351.37   1351.37
# 5662  1999-08-11   1340.59   1365.65   1333.50   1351.47
# 5663  1999-08-10   1364.63   1364.63   1350.15   1357.96
# 5664  1999-08-09   1347.49   1371.15   1347.49   1365.63
#
# [5664 rows x 5 columns]
